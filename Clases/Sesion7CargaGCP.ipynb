# %%
# Instalar SDK Java 8
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
# Descargar Spark 3.4.3

# !wget -q https://archive.apache.org/dist/spark/spark-3.3.4/spark-3.3.4-bin-hadoop3.tgz

# %%
# Descomprimir el archivo descargado de Spark

# !tar xf spark-3.3.4-bin-hadoop3.tgz

# %%
# establecer las variables de entorno
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.3.4-bin-hadoop3"

# %%
# Instalar la librería findspark

# !pip install -q findspark

# %%
# !wget https://repo1.maven.org/maven2/com/google/cloud/bigdataoss/gcs-connector/hadoop3-2.2.9/gcs-connector-hadoop3-2.2.9-shaded.jar
# Out:
# --2025-06-13 22:44:57--  https://repo1.maven.org/maven2/com/google/cloud/bigdataoss/gcs-connector/hadoop3-2.2.9/gcs-connector-hadoop3-2.2.9-shaded.jar
# Resolving repo1.maven.org (repo1.maven.org)... 199.232.192.209, 199.232.196.209, 2a04:4e42:4c::209, ...
# Connecting to repo1.maven.org (repo1.maven.org)|199.232.192.209|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33841633 (32M) [application/java-archive]
# Saving to: ‘gcs-connector-hadoop3-2.2.9-shaded.jar’
#
# gcs-connector-hadoo 100%[===================>]  32.27M   127MB/s    in 0.3s
#
# 2025-06-13 22:44:58 (127 MB/s) - ‘gcs-connector-hadoop3-2.2.9-shaded.jar’ saved [33841633/33841633]

# %%
# !mv gcs-connector-hadoop3-2.2.9-shaded.jar /content/spark-3.3.4-bin-hadoop3/jars

# %%
import findspark

findspark.init()

from pyspark.sql import SparkSession

spark = (SparkSession.builder
         .config("spark.hadoop.fs.gs.impl","com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem")
         .config("google.cloud.auth.service.account.json.keyfile","/content/pyspark.json")
         .getOrCreate())

# %%
df = spark.read.parquet('gs://josemtech/parquet')

df.show()

# %%
df.write.mode('overwrite').parquet('gs://josemtech/salida_parquet')

# %%
df1 = spark.read.option('header', 'true').csv('gs://josemtech/csv')

df1.show()

# %%
f1.write.mode('overwrite').csv('gs://josemtech/salida_csv')
